# %%
#Grab the names and links for each podcast!
import pandas as pd
import requests
import bs4 #BeautifulSoup
import time
import re
import numpy as np

podcast_leading_character = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ*'#Here are possible leading characters for podcast names


#gets the titles of all podcasts on an iTunes podcast category page
def get_podcast_titles_iTunes(soup,target_url = 'https://itunes.apple.com/us/podcast/'):
    
    links = []
    titles = []
    ids = []
    for link in soup.find_all('a'):
        if target_url in link.get('href'):
            links.append(link.get('href'))
            titles.append(link.contents[0])
            ids.append(link.get('href').split("/id",1)[1])
    return links, titles, ids

#count pages on an iTunes podcast category page
def count_pages_iTunes(soup):
    flag = 0
    prev_link = None
    for link in soup.find_all('a'):
        #print(link.contents)
        if link.contents[0]=='#':
            flag = 1
        if(flag):
            if(link.contents[0].isdigit()):
                prev_link = link
            else:
                if(link.contents[0]!='#'):
                    if(prev_link is None):
                        return 1
                    else:
                        return int(prev_link.contents[0])
    raise ValueError()
    
#safe request that keeps on trying if it gets a 403.
def persistent_request(url,retry_time = 60):
    flag = 1
    while(flag):
        page = requests.get(url)
        print(page)
        if(page.status_code!=200):
            flag = 1
            print('Error '+str(page.status_code)+'. Retrying in '+str(retry_time)+' sec')
            time.sleep(retry_time)
        else:
            flag = 0
    return page

inter_query_interval = 0 #seconds
inter_query_variance = 0


#store the podcast name, id, id url, time accessed, and url from where it was obtained. 
url_data = []

# %%
#Grab the names of all of the podcasts from iTunes
#IMPORTANT: these titles are truncated. When searching for id, grab both feed and title

#iterate through leading characters
for c in podcast_leading_character:
    print('######Accessing character '+c)
    #base_url = ('https://itunes.apple.com/us/genre/podcasts-society-culture-history/id1462?mt=2&letter='+c)
    base_url = re.sub('letter=.','letter='+c,'https://itunes.apple.com/us/genre/podcasts-society-culture-history/id1462')
    print(base_url)
    #request first & count pages
    request_time = time.time()
    query_time = np.random.randn()*inter_query_variance+inter_query_interval
    page = persistent_request(base_url)
    soup = bs4.BeautifulSoup(page.text,"html5lib")
    npages = count_pages_iTunes(soup)

    #iterate through page number
    for k in range(1,npages+1):
        print('###Accessing page #'+str(k)+'/'+str(npages))
        if(k!=1):
            #generate url
            url = re.sub('page=.','page='+str(k),hlink)
            request_time = time.time()
            page = persistent_request(url)
            soup = bs4.BeautifulSoup(page.text,"html5lib")
        else:
            url = base_url
        #get podcast titles
        links,titles,ids = get_podcast_titles_iTunes(soup)

        #store the podcast name, id, id url, time accessed, and url from where it was obtained. 
        for x in list(zip(titles,ids,links)):
            url_data.append([x[0],x[1],x[2],request_time,url])

        #file them away
        iter_end_time = time.time()
        duration = iter_end_time - request_time
        time.sleep(max(0,query_time-(duration)))

url_df = pd.DataFrame(url_data,columns=['name','id','url','time_accessed','query_url'])

# %%
url_df['id']=url_df['id'].str.replace('\?mt=2','')

# %%
url_df.head()

# %%
#save the url dataframe
import pickle
floc = '/Users/Jay/AnacondaProjects/plutarch/'
fname = 'podcast_urls.csv'
url_df.to_csv(floc+fname)

# %%
#load in URL dataframe#load i 
import pandas as pd

#load it in
floc = '/Users/Jay/AnacondaProjects/plutarch/'
fname = 'podcast_urls.csv'
url_df = pd.read_csv(floc+fname)
url_df.drop_duplicates(['id'],inplace=True)

# %%
url_df=url_df.drop(columns=['Unnamed: 0'])
url_df

# %%
#Clean up IDs
for rep in range(0,2):
    ids = url_df['id'].get_values()
    for i in range(0,len(ids)):
        #print(i)
        if(isinstance(ids[i],str)):
            if(not ids[i].isdigit()): 
                ids[i] = ids[i].split("/id",1)[1]
    url_df['id'] = ids
    print(url_df['id'])

# %%
#Setup the components of querying the iTunes API for podcast RSS feeds.
import os
import random
#safe request that keeps on trying if it gets a 403.
def persistent_request(url,retry_time = 60):
    flag = 1
    while(flag):
        page = requests.get(url)
        if(page.status_code!=200):
            flag = 1
            print('Error '+str(page.status_code)+'. Retrying in '+str(retry_time)+' sec')
            time.sleep(retry_time)
        else:
            flag = 0
    return page

#wrapper for looking up a set of IDs on iTunes
def lookup_id_iTunes(id):
    return persistent_request('https://itunes.apple.com/lookup?id=' + str(id))

# %%
#Queries the iTunes API to get all of the RSS feeds
import numpy as np
import time
import requests

#setup ID 
def lookup_id_iTunes(id):
    return persistent_request('https://itunes.apple.com/lookup?id=' + str(id))


chunk_size = 200

pages = []
duration = 0
for i in range(0, len(url_df), chunk_size):
    print('###### ' + str(i) + ' to ' + str(i+chunk_size) + 
          ' (last iteration '+ str(np.floor(duration)) + ')' )
    start_time = time.time()
    df_subset = url_df.iloc[i:np.min([len(url_df),(i+chunk_size)])]
    search_url = ','.join([str(x) for x in df_subset['id'].get_values()])
    pages.append(lookup_id_iTunes(search_url))
    print(pages)
    stop_time = time.time()
    duration = stop_time - start_time

# %%
#plot the length of page vectors to make sure that scraping approximately worked
#Each page vector should be of length 200.
import matplotlib.pyplot as plt
from datetime import datetime

page_lengths = [len(x.json()['results']) for x in pages]

plt.figure(figsize=[12,9])
plt.hist(page_lengths)
plt.xlabel('# results')
plt.ylabel('count')
#print(len(url_df))

# %%
#save pages for later processing
import pickle
floc=('/Users/Jay/AnacondaProjects/plutarch/')
pickle.dump(pages,open(floc+'raw_itunes_requests.pkl','wb'))

# %%
#load in raw iTunes requests
import pickle
floc=('/Users/Jay/AnacondaProjects/plutarch/')
raw_itunes_requests = pickle.load(open(floc+'raw_itunes_requests.pkl','rb'))

# %%
#turn everything into a pandas dataframe#turn e 
import pandas as pd

formatted_results = []
bads = []
cnames = ['']
for rir in raw_itunes_requests:
    for p in rir.json()['results']:
        if(p['kind']=='podcast'):
            formatted_results.append(p)

podcast_df = pd.DataFrame(formatted_results)

# %%
podcast_df
# Out:
#          artistId                                         artistName  \
# 0    2.843410e+08                                      HowStuffWorks
# 1    2.562010e+08                                         Dan Carlin
# 2    1.009390e+09                                       Aaron Mahnke
# 3    1.557539e+08                                              Slate
# 4             NaN                                          Mike Rowe
# 5             NaN                                Casefile True Crime
# 6    1.216766e+08                                        BBC Radio 4
# 7    1.216766e+08                                  BBC World Service
# 8    7.123799e+08                                        Mike Duncan
# 9    8.501391e+08                                         Nate DiMeo
# 10            NaN                                 Crimetown Presents
# 11   1.134743e+09                                            Wondery
# 12   1.134743e+09                       Real Crime Profile / Wondery
# 13            NaN                              Richard MacLean Smith
# 14   9.245865e+08                                 BackStory, Panoply
https://is5-ssl.mzstatic.com/image/thumb/Music...
# 10   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 11   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 12   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 13   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 14   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 15   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 16   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 17   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 18   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 19   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 20   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 21   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 22   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 23   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 24   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 25   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 26   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 27   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 28   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 29   https://is3-ssl.mzstatic.com/image/thumb/Music...
# ..                                                 ...
# 210  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 211  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 212  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 213  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 214  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 215  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 216  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 217  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 218  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 219  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 220  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 221  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 222  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 223  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 224  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 225  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 226  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 227  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 228  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 229  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 230  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 231  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 232  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 233  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 234  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 235  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 236  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 237  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 238  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 239  https://is2-ssl.mzstatic.com/image/thumb/Music...
#
#                                          artworkUrl600  \
# 0    https://is2-ssl.mzstatic.com/image/thumb/Music...
# 1    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 2    https://is3-ssl.mzstatic.com/image/thumb/Music...
# 3    https://is5-ssl.mzstatic.com/image/thumb/Music...
# 4    https://is3-ssl.mzstatic.com/image/thumb/Music...
# 5    https://is1-ssl.mzstatic.com/image/thumb/Music...
# 6    https://is5-ssl.mzstatic.com/image/thumb/Music...
# 7    https://is2-ssl.mzstatic.com/image/thumb/Music...
# 8    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 9    https://is5-ssl.mzstatic.com/image/thumb/Music...
# 10   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 11   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 12   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 13   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 14   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 15   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 16   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 17   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 18   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 19   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 20   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 21   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 22   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 23   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 24   https://is2-ssl.mzstatic.com/image/thumb/Music...
# 25   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 26   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 27   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 28   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 29   https://is3-ssl.mzstatic.com/image/thumb/Music...
# ..                                                 ...
# 210  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 211  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 212  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 213  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 214  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 215  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 216  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 217  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 218  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 219  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 220  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 221  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 222  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 223  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 224  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 225  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 226  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 227  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 228  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 229  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 230  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 231  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 232  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 233  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 234  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 235  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 236  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 237  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 238  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 239  https://is2-ssl.mzstatic.com/image/thumb/Music...
#
#                              collectionCensoredName collectionExplicitness  \
# 0                 Stuff You Missed in History Class                cleaned
# 1                     Dan Carlin's Hardcore History                cleaned
# 2                                              Lore                cleaned
# 3                                         Slow Burn            notExplicit
# 4                 The Way I Heard It with Mike Rowe                cleaned
# 5                               Casefile True Crime               explicit
# 6                                       In Our Time                cleaned
# 7                           The Documentary Podcast                cleaned
# 8                               The History of Rome                cleaned
# 9                                 the memory palace                cleaned
# 10                                    The RFK Tapes               explicit
# 11                             The Vanished Podcast                cleaned
# 12                               Real Crime Profile                cleaned
# 13                                      Unexplained                cleaned
# 14                                        BackStory                cleaned
# 15                                      Revolutions                cleaned
# 16                            History Extra podcast                cleaned
# 17                         American History Tellers                cleaned
# 18                                    Heaven's Gate               explicit
# 19                                Hollywood & Crime                cleaned
# 20            Aaron Mahnke's Cabinet of Curiosities            notExplicit
# 21                                        All of It                cleaned
# 22                             Call Your Girlfriend               explicit
# 23                      The British History Podcast                cleaned
# 24                              Conspiracy Theories                cleaned
# 25                              Astonishing Legends                cleaned
# 26                                  History on Fire                cleaned
# 27            A History of the World in 100 Objects                cleaned
# 28                               Ridiculous History            notExplicit
# 29                        Thinking Sideways Podcast                cleaned
# ..                                              ...                    ...
# 210               Every Man a King – FOX News Radio                cleaned
# 211                               Early Middle Ages            notExplicit
# 212     How It Began: A History of the Modern World                cleaned
# 213                                       Liar City               explicit
# 214                     Myths and Legends of Europe                cleaned
# 215                              Viking Age Podcast                cleaned
# 216                    Shakespeare's Restless World                cleaned
# 217                              Twilight Histories                cleaned
# 218                    The History of India Podcast                cleaned
# 219                         Daily Knowledge Podcast            notExplicit
# 220                 The Secret History Of Hollywood                cleaned
# 221             Dark Matters Radio (with Don Ecker)               explicit
# 222              Colonial and Revolutionary America            notExplicit
# 223                           Brief History Podcast                cleaned
# 224             House of Mystery True Crime History                cleaned
# 225                 The American Revolution - Audio            notExplicit
# 226                       WARTIME: A History Series                cleaned
# 227                         La marche de l'histoire                cleaned
# 228                                Mens Rea Podcast               explicit
# 229                                    Horizon Line                cleaned
# 230        European Civilization, 1648-1945 - Audio            notExplicit
# 231                        The Conspirators Podcast                cleaned
# 232                                With Good Reason                cleaned
# 233  The Land of Desire: French History and Culture                cleaned
# 234                           Australian True Crime               explicit
# 235                             [KBS] 다큐멘터리 역사를 찾아서                cleaned
# 236                                  Something True               explicit
# 237                             World War I Podcast                cleaned
# 238                            Noir Factory Podcast                cleaned
# 239             The History of the Cold War Podcast                cleaned
#
#      collectionHdPrice     ...      trackCount trackExplicitness  \
# 0                    0     ...             300           cleaned
# 1                    0     ...              13           cleaned
# 2                    0     ...              99           cleaned
# 3                    0     ...              19       notExplicit
# 4                    0     ...             112           cleaned
# 5                    0     ...             120          explicit
# 6                    0     ...             300           cleaned
# 7                    0     ...             300           cleaned
# 8                    0     ...             192           cleaned
# 9                    0     ...             154           cleaned
# 10                   0     ...              15          explicit
# 11                   0     ...             139           cleaned
# 12                   0     ...             162           cleaned
# 13                   0     ...              64           cleaned
# 14                   0     ...             152           cleaned
# 15                   0     ...             220           cleaned
# 16                   0     ...             300           cleaned
# 17                   0     ...              43           cleaned
# 18                   0     ...              11          explicit
# 19                   0     ...              39           cleaned
# 20                   0     ...              26       notExplicit
# 21                   0     ...               7           cleaned
# 22                   0     ...             186          explicit
# 23                   0     ...             299           cleaned
# 24                   0     ...              28           cleaned
# 25                   0     ...             122           cleaned
# 26                   0     ...              32           cleaned
# 27                   0     ...             100           cleaned
# 28                   0     ...              97       notExplicit
# 29                   0     ...             289           cleaned
# ..                 ...     ...             ...               ...
# 210                  0     ...               2           cleaned
# 211                  0     ...              22       notExplicit
# 212                  0     ...              21           cleaned
# 213                  0     ...              55          explicit
# 214                  0     ...             143           cleaned
# 215                  0     ...              60           cleaned
# 216                  0     ...              20           cleaned
# 217                  0     ...              23           cleaned
# 218                  0     ...             110           cleaned
# 219                  0     ...             300       notExplicit
# 220                  0     ...               9           cleaned
# 221                  0     ...             300          explicit
# 222                  0     ...              25       notExplicit
# 223                  0     ...              21           cleaned
# 224                  0     ...             244           cleaned
# 225                  0     ...              25       notExplicit
# 226                  0     ...             100           cleaned
# 227                  0     ...              63           cleaned
# 228                  0     ...              30          explicit
# 229                  0     ...               6           cleaned
# 230                  0     ...              24       notExplicit
# 231                  0     ...              86           cleaned
# 232                  0     ...             250           cleaned
# 233                  0     ...              44           cleaned
# 234                  0     ...              69          explicit
# 235                  0     ...             271           cleaned
# 236                  0     ...               9          explicit
# 237                  0     ...              62           cleaned
# 238                  0     ...              51           cleaned
# 239                  0     ...              68           cleaned
#
#      trackHdPrice trackHdRentalPrice     trackId  \
# 0               0                  0   283605519
# 1               0                  0   173001861
# 2               0                  0   978052928
# 3               0                  0  1315040130
# 4               0                  0  1087110764
# 5               0                  0   998568017
# 6               0                  0    73330895
# 7               0                  0    73802620
# 219                0  https://itunes.apple.com/us/podcast/daily-know...
# 220                0  https://itunes.apple.com/us/podcast/the-secret...
# 221                0  https://itunes.apple.com/us/podcast/dark-matte...
# 222                0  https://itunes.apple.com/us/podcast/colonial-a...
# 223                0  https://itunes.apple.com/us/podcast/brief-hist...
# 224                0  https://itunes.apple.com/us/podcast/house-of-m...
# 225                0  https://itunes.apple.com/us/podcast/the-americ...
# 226                0  https://itunes.apple.com/us/podcast/wartime-a-...
# 227                0  https://itunes.apple.com/us/podcast/la-marche-...
# 228                0  https://itunes.apple.com/us/podcast/mens-rea-p...
# 229                0  https://itunes.apple.com/us/podcast/horizon-li...
# 230                0  https://itunes.apple.com/us/podcast/european-c...
# 231                0  https://itunes.apple.com/us/podcast/the-conspi...
# 232                0  https://itunes.apple.com/us/podcast/with-good-...
# 233                0  https://itunes.apple.com/us/podcast/the-land-o...
# 234                0  https://itunes.apple.com/us/podcast/australian...
# 235                0  https://itunes.apple.com/us/podcast/kbs-%EB%8B...
# 236                0  https://itunes.apple.com/us/podcast/something-...
# 237                0  https://itunes.apple.com/us/podcast/world-war-...
# 238                0  https://itunes.apple.com/us/podcast/noir-facto...
# 239                0  https://itunes.apple.com/us/podcast/the-histor...
#
#     wrapperType
# 0         track
# 1         track
# 2         track
# 3         track
# 4         track
# 5         track
# 6         track
# 7         track
# 8         track
# 9         track
# 10        track
# 11        track
# 12        track
# 13        track
# 14        track
# 15        track
# 16        track
# 17        track
# 18        track
# 19        track
# 20        track
# 21        track
# 22        track
# 23        track
# 24        track
# 25        track
# 26        track
# 27        track
# 28        track
# 29        track
# ..          ...
# 210       track
# 211       track
# 212       track
# 213       track
# 214       track
# 215       track
# 216       track
# 217       track
# 218       track
# 219       track
# 220       track
# 221       track
# 222       track
# 223       track
# 224       track
# 225       track
# 226       track
# 227       track
# 228       track
# 229       track
# 230       track
# 231       track
# 232       track
# 233       track
# 234       track
# 235       track
# 236       track
# 237       track
# 238       track
# 239       track
#
# [240 rows x 34 columns]

# %%
#take out rows that don't have RSS feeds
import numpy as np
podcast_df = podcast_df.loc[podcast_df['feedUrl'].isnull()==False]

#take out rows that don't have well-defined release dates
podcast_df['releaseDate'] = pd.to_datetime(podcast_df['releaseDate'])
podcast_df = podcast_df.loc[podcast_df['releaseDate'].isnull()==False]
# Out:
# /Applications/anaconda3/envs/insight/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#plot included podcasts as a function of update frequency
from datetime import datetime,timedelta
from matplotlib import pyplot as plt

upper_limit = 100
comparator_day = datetime(2018,9,18,11,5,23,424906)#This was "today" on Monday 6-11-18
npodcast = []
cutoffs = [i for i in range(1,upper_limit+1)]
for c in cutoffs:
    npodcast.append(np.sum(podcast_df['releaseDate'] > (comparator_day - timedelta(days=c))))

plt.plot(cutoffs,npodcast)
plt.xlabel('Time since last update threshold')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %%
#multithreaded RSS scrape
from multiprocessing import Pool
import socket
import time
import feedparser as fp
import requests

MAX_REQUEST_DURATION = 10 #seconds
socket.setdefaulttimeout(MAX_REQUEST_DURATION)

class ResponseCodeError(BaseException):
    pass

def safe_request(url):
    flag = 1
    while(flag):
        page = requests.get(url).json()
        if(page.status_code!=200):
            flag = 1
            print('Error '+str(page.status_code)+'. Retrying in '+str(retry_time)+' sec')
            time.sleep(retry_time)
        else:
            raise ResponseCodeError()
    return page

def feed_request(url):
    try:
        return (url,fp.parse(url))
    except:
        print('Error on ' + url)
        return (url,None)

    
floc = ('/Users/Jay/AnacondaProjects/plutarch/')
if __name__ == '__main__':
    p = Pool(8)
    chunk_size = 8*3
    save_every = 1000; #save and clear rss_feeds after this many feeds have been scraped.
    rss_feeds = []
    bads = []
    duration = 0
    j = 0
    filecounter = 0
    associator = str(int(time.time()))
    for i in range(0,len(podcast_df),chunk_size):
        print('###### ' + str(i) + ' to ' + str(i+chunk_size) + 
          ' (length= ' + str(len(podcast_df))+ '; last iteration '+ str(np.floor(duration)) + ')' )
        start_time = time.time()
        podcast_df.iloc[i:np.min([len(podcast_df),(i+chunk_size)])]
        try:
            rss_feeds.append(p.map(feed_request, podcast_df['feedUrl'].iloc[i:np.min([len(podcast_df),(i+chunk_size)])].get_values()))
        except:
            print('bad on '+ str(i) + ' to ' + str(i+chunk_size))
            for k in range(i,i+chunk_size):
                bads.append(k)
        stop_time = time.time()
        duration = stop_time - start_time
        if(j >= (save_every/chunk_size)):
            print('###Saving...')
            pickle.dump([rss_feeds,bads],open(floc+'raw_rss_and_bads_file'+
                              str(filecounter)+'_'+associator+'.pkl','wb'))
            print('###Saved!')
            #bads = []
            rss_feeds = []
            filecounter+=1
            j = -1
        j += 1
    p.close()
    pickle.dump([rss_feeds,bads],open(floc+'raw_rss_and_bads_file'+
                str(filecounter)+'_'+associator+'.pkl','wb'))
    
print('done!')
# Out:
# ###### 0 to 24 (length= 232; last iteration 0.0)
# ###### 24 to 48 (length= 232; last iteration 6.0)
# ###### 48 to 72 (length= 232; last iteration 5.0)
# ###### 72 to 96 (length= 232; last iteration 3.0)
# ###### 96 to 120 (length= 232; last iteration 7.0)
# ###### 120 to 144 (length= 232; last iteration 6.0)
# bad on 120 to 144
# ###### 144 to 168 (length= 232; last iteration 3.0)
# ###### 168 to 192 (length= 232; last iteration 6.0)
# bad on 168 to 192
# ###### 192 to 216 (length= 232; last iteration 7.0)
# ###### 216 to 240 (length= 232; last iteration 9.0)
# done!

# %%
fname = 'raw_rss_and_bads_file0_1537306068.pkl'
floc=('/Users/Jay/AnacondaProjects/plutarch/')
bads = pickle.load(open(floc+fname,'rb'))[1]

# %%
#iterate through bads
import numpy as np
import time
import feedparser as fp
import requests


class ResponseCodeError(BaseException):
    pass

def safe_request(url):
    flag = 1
    while(flag):
        page = requests.get(url).json()
        if(page.status_code!=200):
            flag = 1
            print('Error '+str(page.status_code)+'. Retrying in '+str(retry_time)+' sec')
            time.sleep(retry_time)
        else:
            raise ResponseCodeError()
    return page

def feed_request(url):
    try:
        return (url,fp.parse(url))
    except:
        print('Error on ' + url)
        return (url,None)

#load in raw_rss_and_bads_file48_1528758749.pkl for a list of bads

bad_list = bads
rss_feeds = []
floc=('/Users/Jay/AnacondaProjects/plutarch/')
save_every = 1000; #save and clear rss_feeds after this many feeds have been scraped.
bad_feeds = []
badbads = []
duration = 0
j = 0
filecounter = 56
associator = 1528772780
for i in range(0,len(bad_list)):
    print('###### ' + str(i) + ' to ' + str(len(bad_list)) + 
      ' (last iteration '+ str(np.floor(duration)) + ')' )
    start_time = time.time()
    bad_feeds.append(feed_request(podcast_df['feedUrl'].iloc[bad_list[i]]))
    stop_time = time.time()
    duration = stop_time - start_time
    if(j >= save_every):
        print('###Saving...')
        pickle.dump([bad_feeds,bads],open(floc+'raw_rss_and_bads_file'+
                              str(filecounter)+'_'+str(associator)+'.pkl','wb'))
        print('###Saved!')
        bad_feeds = []
        filecounter+=1
        j = -1
    j += 1

pickle.dump([bad_feeds,bads],open(floc+'raw_rss_and_bads_file'+
                              str(filecounter)+'_'+str(associator)+'.pkl','wb'))
# Out:
# ###### 0 to 48 (last iteration 0.0)
# ###### 1 to 48 (last iteration 0.0)
# ###### 2 to 48 (last iteration 0.0)
# ###### 3 to 48 (last iteration 0.0)
# ###### 4 to 48 (last iteration 0.0)
# ###### 5 to 48 (last iteration 0.0)
# ###### 6 to 48 (last iteration 2.0)
# ###### 7 to 48 (last iteration 0.0)
# ###### 8 to 48 (last iteration 0.0)
# ###### 9 to 48 (last iteration 0.0)
# ###### 10 to 48 (last iteration 0.0)
# ###### 11 to 48 (last iteration 1.0)
# ###### 12 to 48 (last iteration 0.0)
# ###### 13 to 48 (last iteration 1.0)
# ###### 14 to 48 (last iteration 1.0)
# ###### 15 to 48 (last iteration 0.0)
# ###### 16 to 48 (last iteration 0.0)
# ###### 17 to 48 (last iteration 1.0)
# ###### 18 to 48 (last iteration 0.0)
# ###### 19 to 48 (last iteration 0.0)
# ###### 20 to 48 (last iteration 1.0)
# ###### 21 to 48 (last iteration 0.0)
# ###### 22 to 48 (last iteration 0.0)
# ###### 23 to 48 (last iteration 0.0)
# ###### 24 to 48 (last iteration 0.0)
# ###### 25 to 48 (last iteration 0.0)
# ###### 26 to 48 (last iteration 0.0)
# ###### 27 to 48 (last iteration 0.0)
# ###### 28 to 48 (last iteration 1.0)
# ###### 29 to 48 (last iteration 0.0)
# ###### 30 to 48 (last iteration 0.0)
# ###### 31 to 48 (last iteration 1.0)
# ###### 32 to 48 (last iteration 0.0)
# ###### 33 to 48 (last iteration 0.0)
# ###### 34 to 48 (last iteration 0.0)
# ###### 35 to 48 (last iteration 1.0)
# ###### 36 to 48 (last iteration 0.0)
# ###### 37 to 48 (last iteration 0.0)
# ###### 38 to 48 (last iteration 0.0)
# ###### 39 to 48 (last iteration 0.0)
# ###### 40 to 48 (last iteration 0.0)
# ###### 41 to 48 (last iteration 0.0)
# ###### 42 to 48 (last iteration 0.0)
# ###### 43 to 48 (last iteration 4.0)
# ###### 44 to 48 (last iteration 1.0)
# ###### 45 to 48 (last iteration 0.0)
# ###### 46 to 48 (last iteration 1.0)
# ###### 47 to 48 (last iteration 0.0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-da1895d7486c> in <module>()
#      58
#      59 pickle.dump([bad_feeds,bads],open(floc+'raw_rss_and_bads_file'+
# ---> 60                               str(filecounter)+'_'+str(associator)+'.pkl','wb'))
#
# ValueError: I/O operation on closed file.
